# %%
age_list = [34,25,23,19,29,41]
max_age = max(age_list)
max_age
# Out:
# 41

# %%
max_age = str(max_age)
max_age
# Out:
# '41'

# %%
max_age = 'Ninety-Nine'
max_age
# Out:
# 'Ninety-Nine'

# %%
max_age
# Out:
# 41

# %%
min_age = min(age_list)

max_age - min_age
# Out:
# 22
